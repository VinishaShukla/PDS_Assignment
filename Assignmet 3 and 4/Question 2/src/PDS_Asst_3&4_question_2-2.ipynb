# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/data_cleaned.csv')

# Check for missing values
data.isna().sum()
# Out:
# Unnamed: 0                  0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Set seed for reproducibility
np.random.seed(950)

# Sample 25 observations
sample = data.sample(25)

# Calculate population statistics
population_mean_glucose = data['Glucose'].mean()
population_max_glucose = data['Glucose'].max()

# Calculate sample statistics
sample_mean_glucose = sample['Glucose'].mean()
sample_max_glucose = sample['Glucose'].max()

# Define labels and values for bar chart
labels = ['Population Mean', 'Population Max', 'Sample Mean', 'Sample Max']
values = [population_mean_glucose, population_max_glucose, sample_mean_glucose, sample_max_glucose]
colors = ['pink', 'purple', 'pink', 'purple']

# Create bar chart
plt.bar(labels, values, color=colors)
plt.title('Comparison of Glucose Statistics')
plt.ylabel('Glucose Values')
plt.show()

# %%
# Calculate population and sample 98th percentiles
population_percentile = np.percentile(data['BMI'], 98)
sample_percentile = np.percentile(sample['BMI'], 98)

# Define labels and values for bar chart
labels = ['Population 98th Percentile', 'Sample 98th Percentile']
values = [population_percentile, sample_percentile]
colors = ['pink', 'purple']

# Create bar chart
plt.bar(labels, values, color=colors)
plt.title('Comparison of BMI 98th Percentiles')
plt.ylabel('BMI Values')
plt.show()

# %%
# Calculate the average of the 25th, 50th, and 75th percentiles
average_percentile_value = np.mean(population_percentiles)

# Define labels and data for the bar graph
labels = ['Mean', 'Std', '25th Percentile', '50th Percentile', '75th Percentile', 'Average Percentile']
bootstrap_values = [avg_bootstrap_mean, avg_bootstrap_std, avg_bootstrap_percentiles[0], avg_bootstrap_percentiles[1], avg_bootstrap_percentiles[2], average_percentile_value]
population_values = [population_mean, population_std, population_percentiles[0], population_percentiles[1], population_percentiles[2], average_percentile_value]

# Define colors for bootstrap and population bars
bootstrap_color = 'pink'
population_color = 'purple'

# Calculate the number of bars
num_bars = len(labels)

# Create the bar graph
bar_width = 0.35
index = np.arange(num_bars)

plt.bar(index, bootstrap_values, bar_width, alpha=0.5, label='Bootstrap', color=bootstrap_color)
plt.bar(index + bar_width, population_values, bar_width, alpha=0.5, label='Population', color=population_color)

plt.xlabel('Statistics')
plt.ylabel('Value')
plt.title('Comparison of Bootstrap and Population Statistics')
plt.xticks(rotation=45, ha='right')
plt.xticks(index + bar_width / 2, labels)
plt.legend()

plt.show()
